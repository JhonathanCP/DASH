# %%
import dash
from dash import dcc, html
from dash.dependencies import Input, Output, State
import plotly.express as px
import pandas as pd
from sqlalchemy import create_engine
import plotly.graph_objects as go
import dash_bootstrap_components as dbc
from dash import dash_table
import numpy as np
from jupyter_dash import JupyterDash
import pdfkit
import base64
from io import BytesIO
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas
import pyodbc
from urllib.parse import quote_plus
import io
import oracledb
from datetime import datetime
from dash.exceptions import PreventUpdate
import csv

# %%
def csv_to_dict_of_lists(file_path):
    with open(file_path, mode='r', encoding='utf-8') as file:
        csv_reader = csv.DictReader(file)
        data = {}
        
        for row in csv_reader:
            for column, value in row.items():
                if column in data:
                    data[column].append(value)
                else:
                    data[column] = [value]
                    
    return data

# Ejemplo de uso
file_path = 'C:/Users/Kings/Downloads/extrac.csv'
data_dict = csv_to_dict_of_lists(file_path)

# Imprimir el diccionario
print(data_dict)
# Out:
# {'COD_IPRESS': ['8577', '8577', '8577', '8577', '8577', '8577', '8577', '8577', '8577', '8577'], 'IPRESS': ['CENTRO 1', 'CENTRO 1', 'CENTRO 1', 'CENTRO 1', 'CENTRO 1', 'CENTRO 1', 'CENTRO 1', 'CENTRO 1', 'CENTRO 1', 'CENTRO 1'], 'NOMBRED': ['RED 1', 'RED 1', 'RED 1', 'RED 1', 'RED 1', 'RED 1', 'RED 1', 'RED 1', 'RED 1', 'RED 1'], 'TIPDOCUMENTO': ['DNI', 'DNI', 'DNI', 'DNI', 'DNI', 'DNI', 'DNI', 'DNI', 'DNI', 'DNI'], 'NUMDOCUMENTO': ['12345678', '12234568', '23546875', '86544878', '56452317', '98745631', '45612387', '78987426', '32144567', '98798753'], 'COLEGIOPROF': ['COP', 'COP', 'COP', 'CEP', 'CMP', 'CMP', 'CNP', 'CTSP', 'CTSP', 'CTMP'], 'NUMCOLEGIO': ['25338', '10132', '4529', '56093', '38143', '37974', '6607', '11503', '10154', '4634'], 'APELLIDOS': ['APELLIDO 1', 'APELLIDO 2', 'APELLIDO 3', 'APELLIDO 4', 'APELLIDO 5', 'APELLIDO 6', 'APELLIDO 7', 'APELLIDO 8', 'APELLIDO 9', 'APELLIDO 10'], 'NOMBRES': ['NOMBRE 1', 'NOMBRE 2', 'NOMBRE 3', 'NOMBRE 4', 'NOMBRE 5', 'NOMBRE 6', 'NOMBRE
# ...

# %%
dataMuestra= {'COD_IPRESS': ['8577', '8577', '8577', '8577', '8577', '8577', '8577', '8577', '8577', '8577'], 'IPRESS': ['CENTRO 1', 'CENTRO 1', 'CENTRO 1', 'CENTRO 1', 'CENTRO 1', 'CENTRO 1', 'CENTRO 1', 'CENTRO 1', 'CENTRO 1', 'CENTRO 1'], 'NOMBRED': ['RED 1', 'RED 1', 'RED 1', 'RED 1', 'RED 1', 'RED 1', 'RED 1', 'RED 1', 'RED 1', 'RED 1'], 'TIPDOCUMENTO': ['DNI', 'DNI', 'DNI', 'DNI', 'DNI', 'DNI', 'DNI', 'DNI', 'DNI', 'DNI'], 'NUMDOCUMENTO': ['12345678', '12234568', '23546875', '86544878', '56452317', '98745631', '45612387', '78987426', '32144567', '98798753'], 'COLEGIOPROF': ['COP', 'COP', 'COP', 'CEP', 'CMP', 'CMP', 'CNP', 'CTSP', 'CTSP', 'CTMP'], 'NUMCOLEGIO': ['25338', '10132', '4529', '56093', '38143', '37974', '6607', '11503', '10154', '4634'], 'APELLIDOS': ['APELLIDO 1', 'APELLIDO 2', 'APELLIDO 3', 'APELLIDO 4', 'APELLIDO 5', 'APELLIDO 6', 'APELLIDO 7', 'APELLIDO 8', 'APELLIDO 9', 'APELLIDO 10'], 'NOMBRES': ['NOMBRE 1', 'NOMBRE 2', 'NOMBRE 3', 'NOMBRE 4', 'NOMBRE 5', 'NOMBRE 6', 'NOMBRE 7', 'NOMBRE 8', 'NOMBRE 9', 'NOMBRE 10'], 'ESPECIALIDAD': ['ODONTOLOGIA', 'ODONTOLOGIA', 'ODONTOLOGIA', 'ENFERMERIA', 'CIRUGIA GENERAL', 'CIRUGIA GENERAL', 'NUTRICION', 'SERVICIO SOCIAL', 'SERVICIO SOCIAL', 'TECNOLOGO MEDICO DE RADIOLOGIA'], 'SERVICIO': ['UPSS - CONSULTA EXTERNA', 'UPS
'DIA18_SALIDA': ['', '', '', '', '', '', '16:00', '', '', ''], 'DIA19_INGRESO': ['08:00', '', '', '', '', '', '13:00', '', '08:00', '07:30'], 'DIA19_SALIDA': ['12:00', '', '', '', '', '', '16:00', '', '10:00', '13:30'], 'DIA20_INGRESO': ['', '', '', '', '', '', '', '', '', '07:30'], 'DIA20_SALIDA': ['', '', '', '', '', '', '', '', '', '13:30'], 'DIA21_INGRESO': ['08:00', '08:00', '', '07:00', '', '', '13:00', '', '', '07:30'], 'DIA21_SALIDA': ['12:00', '14:00', '', '13:00', '', '', '16:00', '', '', '13:30'], 'DIA22_INGRESO': ['', '', '', '07:00', '', '20:00', '', '', '', '07:30'], 'DIA22_SALIDA': ['', '', '', '13:00', '', '08:00', '', '', '', '13:30'], 'DIA23_INGRESO': ['08:00', '08:00', '', '', '08:00', '', '', '', '08:00', '07:30'], 'DIA23_SALIDA': ['12:00', '14:00', '', '', '20:00', '', '', '', '10:00', '13:30'], 'DIA24_INGRESO': ['', '', '08:00', '07:00', '', '', '13:00', '', '', '07:30'], 'DIA24_SALIDA': ['', '', '14:00', '13:00', '', '', '16:00', '', '', '13:30'], 'DIA25_INGRESO': ['', '', '', '', '08:00', '', '', '', '', ''], 'DIA25_SALIDA': ['', '', '', '', '20:00', '', '', '', '', ''], 'DIA26_INGRESO': ['08:00', '', '', '', '', '', '', '', '', '07:30'], 'DIA26_SALIDA': ['12:00', '', '', '', '', '', '', '', '', '13:30'], 'DIA27_INGRESO': ['', '', '', '07:00', '', '', '', '', '', '07:30'], 'DIA27_SALIDA': ['', '', '', '13:00', '', '', '', '', '', '13:30'], 'DIA28_INGRESO': ['08:00', '08:00', '', '', '', '', '', '', '', '07:30'], 'DIA28_SALIDA': ['12:00', '14:00', '', '', '', '', '', '', '', '13:30'], 'DIA29_INGRESO': ['', '', '', '07:00', '', '20:00', '13:00', '', '08:00', '07:30'], 'DIA29_SALIDA': ['', '', '', '13:00', '', '08:00', '16:00', '', '10:00', '13:30'], 'DIA30_INGRESO': ['', '', '', '07:00', '08:00', '', '13:00', '', '', ''], 'DIA30_SALIDA': ['', '', '', '13:00', '20:00', '', '16:00', '', '', ''], 'DIA31_INGRESO': ['', '', '', '', '', '20:00', '13:00', '', '', ''], 'DIA31_SALIDA': ['', '', '', '', '', '08:00', '16:00', '', '', '']}
dm = pd.DataFrame(dataMuestra)
dm
# Out:
#   COD_IPRESS    IPRESS NOMBRED TIPDOCUMENTO NUMDOCUMENTO COLEGIOPROF  \
# 0       8577  CENTRO 1   RED 1          DNI     12345678         COP
# 1       8577  CENTRO 1   RED 1          DNI     12234568         COP
# 2       8577  CENTRO 1   RED 1          DNI     23546875         COP
# 3       8577  CENTRO 1   RED 1          DNI     86544878         CEP
# 4       8577  CENTRO 1   RED 1          DNI     56452317         CMP
# 5       8577  CENTRO 1   RED 1          DNI     98745631         CMP
# 6       8577  CENTRO 1   RED 1          DNI     45612387         CNP
# 7       8577  CENTRO 1   RED 1          DNI     78987426        CTSP
# 8       8577  CENTRO 1   RED 1          DNI     32144567        CTSP
# 9       8577  CENTRO 1   RED 1          DNI     98798753        CTMP
#
#   NUMCOLEGIO    APELLIDOS    NOMBRES                    ESPECIALIDAD  ...  \
# 0      25338   APELLIDO 1   NOMBRE 1                     ODONTOLOGIA  ...
# ...
